# %% [markdown]
# <a href="https://colab.research.google.com/github/jatavor1/AppleStock/blob/main/appleTestTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Data/AAPL_data.csv')

# %%
data.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
data['date'] == pd.to_datetime(data['date'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1254    True
# 1255    True
# 1256    True
# 1257    True
# 1258    True
# Name: date, Length: 1259, dtype: bool

# %%
data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
import plotly.express as px

# %%
tList = data['Name'].unique()

# %%
for company in (tList):
    df = data[data['Name'] == company]
    graph =  px.line(df , x = "date", y = "volume" , title = "Apple")
    graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(data.corr())
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999584  0.999515  0.999118 -0.617862
# high    0.999584  1.000000  0.999382  0.999584 -0.612622
# low     0.999515  0.999382  1.000000  0.999614 -0.625910
# close   0.999118  0.999584  0.999614  1.000000 -0.620290
# volume -0.617862 -0.612622 -0.625910 -0.620290  1.000000
# <ipython-input-13-40835d1ef585>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
import numpy as np

# %%
# !pip install autots
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.0 MB/s eta 0:00:00
# ...

# %%
from autots import AutoTS

# %%
model = AutoTS(forecast_length=5, frequency='infer', ensemble='simple')

# %%
model = model.fit(data, date_col='date', value_col='close', id_col=None)
# Out:
# Inferred frequency is: B
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
prediction = model.predict()

# %%
forecast = prediction.forecast

# %%
print(forecast)
# Out:
#                  close
# 2018-02-08  158.153646
# 2018-02-09  156.497676
# 2018-02-12  155.016843
# 2018-02-13  153.496633
# 2018-02-14  152.021105

# %%
data.tail()
# Out:
#             date     open    high       low   close    volume  Name
# 1254  2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 1255  2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 1256  2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 1257  2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 1258  2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
